# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cancer_data = pd.read_csv('Cancer_Data.csv')

# %%
cancer_data.head()
# Out:
#    Unnamed: 0 diagnosis children  radius_mean  texture_mean  perimeter_mean  \
# 0           0         M      Yes        17.99         10.38          122.80
# 1           1         M       No        20.57         17.77          132.90
# 2           2         M      Yes        19.69         21.25          130.00
# 3           3         M       No        11.42         20.38           77.58
# 4           4         M      Yes        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760          0.3001
# 1     1326.0          0.08474           0.07864          0.0869
# 2     1203.0          0.10960           0.15990          0.1974
# 3      386.1          0.14250           0.28390          0.2414
# 4     1297.0          0.10030           0.13280          0.1980
#
#             ...             radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
cancer_data = cancer_data.drop(columns = ['Unnamed: 0'])
cancer_data.head()
# Out:
#   diagnosis children  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M      Yes        17.99         10.38          122.80     1001.0
# 1         M       No        20.57         17.77          132.90     1326.0
# 2         M      Yes        19.69         21.25          130.00     1203.0
# 3         M       No        11.42         20.38           77.58      386.1
# 4         M      Yes        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
x = np.arange(len(cancer_data))

fig = plt.figure(figsize=(10,4), dpi=100)
plt.plot(x,  cancer_data['radius_mean'], 'skyblue')
plt.xlabel('#')
plt.ylabel('Radius Mean')
plt.title('Line Plot for Radius Mean')
plt.show()

# %%
fig = plt.figure(figsize=(10,4), dpi=100)
plt.scatter(x, cancer_data['radius_mean'])
plt.xlabel('#')
plt.ylabel('Radius Mean')
plt.title('Dot Plot for Radius Mean')
plt.show()

# %%
fig = plt.figure(figsize=(10,4), dpi=100)
plt.hist(cancer_data['radius_mean'], bins = 50, color = 'red', alpha = 0.5)
plt.xlabel('#')
plt.ylabel('Radius Mean')
plt.title('Histogram Plot for Radius Mean')
plt.show()

# %%
cancer_data['radius_mean'].hist() #Histogram of Radius_mean

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
cancer_data['radius_mean'].hist() #Histogram of Radius_mean

# %%
plt.style.use('bmh')
cancer_data['texture_mean'].hist()

# %%
plt.style.use('dark_background')
cancer_data['texture_mean'].hist()

# %%
plt.style.use('fivethirtyeight')
cancer_data['texture_mean'].hist()
