# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the data
cancer_data = pd.read_csv('Breast_Cancer_Wisconsin.csv')

# %%
#View the first 5 rows of data
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %% [markdown]
# __Get the mean of radius_mean__

# %%
cancer_data['radius_mean'].mean()
# Out:
# 14.127291739894563

# %% [markdown]
# __Get the highest and lowest radius_mean__

# %%
cancer_data['radius_mean'].max()
# Out:
# 28.11

# %% [markdown]
# __Drop the ID and Unnamed columns__

# %%
cancer_data = cancer_data.drop(columns = ['id', 'Unnamed: 32'])
cancer_data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %% [markdown]
# # Group Data

# %%
#Group by Dianosis
by_type = cancer_data.groupby('diagnosis')
by_type.mean()
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# B            12.146524     17.914762       78.075406  462.790196
# M            17.462830     21.604906      115.365377  978.376415
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B                 0.092478          0.080085        0.046058
# M                 0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  \
# diagnosis
# B                     0.025717       0.174186                0.062867
# M                     0.087990       0.192909                0.062680
#
#                     ...             radius_worst  texture_worst  \
# diagnosis           ...
# B                   ...                13.379801      23.515070
# M                   ...                21.134811      29.318208
#
#            perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# diagnosis
# ...

# %%
#Get the std. dev
by_type.std()
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# B             1.780512      3.995125       11.807438  134.287118
# M             3.203971      3.779470       21.854653  367.937978
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B                 0.013446          0.033750        0.043442
# M                 0.012608          0.053987        0.075019
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  \
# diagnosis
# B                     0.015909       0.024807                0.006747
# M                     0.034374       0.027638                0.007573
#
#                     ...             radius_worst  texture_worst  \
# diagnosis           ...
# B                   ...                 1.981368       5.493955
# M                   ...                 4.283569       5.434804
#
#            perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# diagnosis
# ...

# %%
#Count the number of bytype
by_type.count()
# Out:
#            radius_mean  texture_mean  perimeter_mean  area_mean  \
# diagnosis
# B                  357           357             357        357
# M                  212           212             212        212
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B                      357               357             357
# M                      212               212             212
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  \
# diagnosis
# B                          357            357                     357
# M                          212            212                     212
#
#                     ...             radius_worst  texture_worst  \
# diagnosis           ...
# B                   ...                      357            357
# M                   ...                      212            212
#
#            perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# diagnosis
# ...

# %%
#Describe the radius_mean

# %%
by_type.describe().transpose()['B'].radius_mean
# Out:
# count    357.000000
# mean      12.146524
# std        1.780512
# min        6.981000
# 25%       11.080000
# 50%       12.200000
# 75%       13.370000
# max       17.850000
# Name: B, dtype: float64

# %% [markdown]
# # Subset Observations

# %%
#Get the data that has the radius mean < 10 and concavity_worst < 0.2
cancer_data[(cancer_data['radius_mean'] < 10) &(cancer_data['concavity_worst'] < 0.2)]
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 21          B        9.504         12.44           60.34      273.9
# 46          B        8.196         16.84           51.71      201.9
# 59          B        8.618         11.79           54.34      224.5
# 61          B        8.598         20.98           54.66      221.8
# 63          B        9.173         13.86           59.20      260.9
# 66          B        9.465         21.01           60.11      269.4
# 71          B        8.888         14.64           58.79      244.0
# 97          B        9.787         19.94           62.11      294.5
# 101         B        6.981         13.43           43.79      143.5
# 110         B        9.777         16.99           62.50      290.2
# 116         B        8.950         15.76           58.74      245.2
# 140         B        9.738         11.97           61.24      288.5
# 175         B        8.671         14.45           54.42      227.2
# ...

# %%
#Randomly select fraction of rows. Fraction = 0.01
cancer_data.sample(frac = 0.01)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 502         B        12.54         16.32           81.25      476.3
# 194         M        14.86         23.21          100.40      671.4
# 245         B        10.48         19.86           66.72      337.7
# 144         B        10.75         14.97           68.26      355.3
# 527         B        12.34         12.27           78.94      468.5
# 181         M        21.09         26.57          142.70     1311.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 502          0.11580           0.10850         0.05928             0.032790
# 194          0.10440           0.19800         0.16970             0.088780
# 245          0.10700           0.05971         0.04831             0.030700
# 144          0.07793           0.05139         0.02251             0.007875
# 527          0.09003           0.06307         0.02958             0.026470
# ...

# %%
#Randomly select n rows
cancer_data.sample(n = 10) #Select 10 random rows
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 333         B       11.250         14.78           71.38      390.0
# 206         B        9.876         17.27           62.92      295.4
# 354         B       11.140         14.07           71.24      384.6
# 410         B       11.360         17.57           72.49      399.8
# 302         M       20.090         23.86          134.70     1247.0
# 76          B       13.530         10.94           87.91      559.2
# 176         B        9.904         18.06           64.60      302.4
# 51          B       13.640         16.34           87.21      571.8
# 517         M       19.890         20.26          130.50     1214.0
# 564         M       21.560         22.39          142.00     1479.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 333          0.08306           0.04458        0.000974             0.002941
# ...

# %%
#Select and order top n entries
cancer_data.nlargest(5, 'radius_mean') #Select the top 5 radius_mean
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 212         M        28.11         18.47           188.5     2499.0
# 461         M        27.42         26.27           186.9     2501.0
# 180         M        27.22         21.87           182.1     2250.0
# 352         M        25.73         17.46           174.2     2010.0
# 82          M        25.22         24.91           171.5     1878.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 212           0.1142            0.1516          0.3201               0.1595
# 461           0.1084            0.1988          0.3635               0.1689
# 180           0.1094            0.1914          0.2871               0.1878
# 352           0.1149            0.2363          0.3368               0.1913
# 82            0.1063            0.2665          0.3339               0.1845
#
#      symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
#Sort rows by values of columns
cancer_data.sort_values('smoothness_mean', ascending = False)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 504         B        9.268         12.87           61.49      248.7
# 122         M       24.250         20.20          166.20     1761.0
# 3           M       11.420         20.38           77.58      386.1
# 105         M       13.110         15.56           87.21      530.2
# 520         B        9.295         13.90           59.96      257.8
# 257         M       15.320         17.27          103.20      713.3
# 108         M       22.270         19.67          152.80     1509.0
# 203         M       13.810         23.75           91.56      597.8
# 76          B       13.530         10.94           87.91      559.2
# 78          M       20.180         23.97          143.70     1245.0
# 5           M       12.450         15.70           82.57      477.1
# 8           M       13.000         21.82           87.50      519.8
# 172         M       15.460         11.89          102.50      736.9
# ...

# %%
cancer_data.to_csv('Cancer_Data.csv') #Export the data
