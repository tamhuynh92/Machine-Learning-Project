# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cancer_data = pd.read_csv('Cancer_Data.csv')
cancer_data = cancer_data.drop(columns = ['Unnamed: 0'])
cancer_data = cancer_data.iloc[:,:12]
cancer_data.head()
# Out:
#   diagnosis children  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M      Yes        17.99         10.38          122.80     1001.0
# 1         M       No        20.57         17.77          132.90     1326.0
# 2         M      Yes        19.69         21.25          130.00     1203.0
# 3         M       No        11.42         20.38           77.58      386.1
# 4         M      Yes        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# ...

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Categorical Data Plots

# %%
sns.set()
plt.rcParams["patch.force_edgecolor"] = True

sns.barplot(x='diagnosis',y='radius_mean',data= cancer_data) #Mean plot

# %%
sns.barplot(x='diagnosis',y='radius_mean',data= cancer_data, estimator=np.std) #Std PLot

# %%
sns.countplot(x='diagnosis',data= cancer_data) #Count plot

# %%
sns.boxplot(x='diagnosis',y='radius_mean', hue = 'children', data= cancer_data,palette='rainbow') #Boxplot of Diagnosis type for radius_mean

# %%
sns.boxplot(x='diagnosis',y='radius_mean', data= cancer_data,palette='rainbow')

# %%
sns.violinplot(x='diagnosis',y='radius_mean', data= cancer_data,palette='rainbow')

# %%
sns.stripplot(x='diagnosis',y='radius_mean', data= cancer_data,palette='rainbow')

# %%
sns.stripplot(x='diagnosis',y='radius_mean', hue = 'children', data= cancer_data, jitter=True)

# %%
sns.stripplot(x='diagnosis',y='radius_mean', data= cancer_data,jitter=True,hue='children',palette='Set1',split=True)
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='diagnosis',y='radius_mean', data= cancer_data, hue='children', palette="Set1", split=True)
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:2783: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Distribution Plot

# %%
sns.distplot(cancer_data['radius_mean'])
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(cancer_data['radius_mean'],kde=False,bins=30)
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='radius_mean',y='texture_mean',data= cancer_data,kind='scatter')
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='radius_mean',y='texture_mean',data= cancer_data,kind='hex')
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='radius_mean',y='texture_mean',data= cancer_data,kind='reg')
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(cancer_data, vars = ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 
                                  'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 
                                  'symmetry_mean'])

# %%
sns.pairplot(cancer_data, vars = ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 
                                  'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 
                                  'symmetry_mean'], hue = 'children', palette="husl")

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(cancer_data.corr())

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(cancer_data.corr(),cmap='coolwarm',annot=True)

# %%
sns.lmplot(x='radius_mean',y='texture_mean',data= cancer_data ,hue='diagnosis',palette='coolwarm',
          aspect=0.6,size=8)

# %%
sns.lmplot(x='radius_mean',y='texture_mean', row="children", col="diagnosis",data= cancer_data)

# %%
features_mean= list(cancer_data.columns[2:13])
plt.figure(figsize=(15,15))
for i, feature in enumerate(features_mean):
    rows = int(len(features_mean)/2) + 1
    
    plt.subplot(rows, 2, i+1)
    
    sns.boxplot(x='diagnosis', y=feature, data=cancer_data, palette="Set1")

plt.tight_layout()
plt.show()

# %%
bins = 12
plt.figure(figsize=(15,15))
for i, feature in enumerate(features_mean):
    rows = int(len(features_mean)/2)
    
    plt.subplot(rows, 2, i+1)
    
    sns.distplot(cancer_data[cancer_data['diagnosis']=='M'][feature], bins=bins, color='red', label='M');
    sns.distplot(cancer_data[cancer_data['diagnosis']=='B'][feature], bins=bins, color='blue', label='B');
    
    plt.legend(loc='upper right')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\JFP1141\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
# ...

# %%
features_mean
